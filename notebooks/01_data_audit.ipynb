# %%
import pandas as pd

# %%
df = pd.read_csv("/home/s1h/Projects/Datasets/Synthetic_Financial_datasets_log.csv")

# %%
df.shape
# Out:
# (6362620, 11)

# %% [markdown]
# - row count
# - column count
# - column types
# - missing values
# - duplicates
# - target balance
# - timestamp coverage
# - amount distribution
# - categorical cardinality
# - customer frequency
# - merchant frequency
# - suspicious values
# - impossible values
